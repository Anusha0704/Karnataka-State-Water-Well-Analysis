# %% [markdown]
# # EDA (Exploratory Data Analysis) Steps :

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sklearn
import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('admission_predict.csv')
print(df)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
print("datashow.columns",df.columns)
# Out:
# datashow.columns Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#df.shape tells us the number of rows and columns present in the dataset

print('The shape of our dataframe is:', df.shape)
# Out:
# The shape of our dataframe is: (500, 9)

# %%
# To get the general information of the dataframe we use info() function of the pandas library
# Removing the serial no column

df=df.iloc[:,1:]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
# To get the summary of the statistics of the dataset describe function is used

df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %%
# The Starting values of the dataset are found using head() function

df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
# The Ending values of the dataset are found using tail() function

df.tail()
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 495              0.87
# 496              0.96
# 497              0.93
# 498              0.73
# 499              0.84

# %% [markdown]
# ## Identifying the outliers

# %%
# Checking if there are any outliers by checking the difference between median and mean.
# If the difference is greater than 2.5 then an outlier is said to be found.

print("GRE Score: mean =",df['GRE Score'].mean(),",median =",df['GRE Score'].median())
print("TOEFL Score: mean =",df['TOEFL Score'].mean(),",median =",df['TOEFL Score'].median())
print("University Rating: mean =",df['University Rating'].mean(),",median =",df['University Rating'].median())
print("SOP: mean =",df['SOP'].mean(),",median=",df['SOP'].median())
print("LOR: mean =",df['LOR '].mean(),",median=",df['LOR '].median())
print("CGPA: mean =",df['CGPA'].mean(),",median= ",df['CGPA'].median())
print("Research: mean =",df['Research'].mean(),",median=",df['Research'].median())
print("Chance of Admit: mean= ",df['Chance of Admit '].mean(),",median=",df['Chance of Admit '].median())

# Since the difference between the median and mean is very small there are no outliers in the columns of the dataset
# Out:
# GRE Score: mean = 316.472 ,median = 317.0
# TOEFL Score: mean = 107.192 ,median = 107.0
# University Rating: mean = 3.114 ,median = 3.0
# SOP: mean = 3.374 ,median= 3.5
# LOR: mean = 3.484 ,median= 3.5
# CGPA: mean = 8.576439999999998 ,median=  8.56
# Research: mean = 0.56 ,median= 1.0
# Chance of Admit: mean=  0.72174 ,median= 0.72

# %%
# Checking if there are any missing values(Nan values) in the dataset

df.isna().sum()

# There are no missing values
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# A pairs plot allows us to see both distribution of single variables and relationships between two variables.
# The pairs plot builds on two figures, the histogram and the scatter plot. 

sns.pairplot(df)

# %%
# The heatmap is a way of representing the data in a 2-dimensional form.
# The data values are represented as colors in the graph.
# The goal of the heatmap is to provide a colored visual summary of information.

corr = df.corr()
sns.heatmap(corr, vmax=0.9,vmin=0,annot=True,cmap="YlGnBu")
corr
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398          0.810351
# TOEFL Score        0.541563  0.810574  0.467012          0.792228
# University Rating  0.608651  0.705254  0.427047          0.690132
# ...

# %%
# The histogram allows us to see the distribution of a single variable

df.hist(figsize=(12,8))
plt.show()

# %%
# Histogram of chance of admission

plt.figure(figsize=(12,8))
plt.hist(df['Chance of Admit '],bins=10,color="orange")
plt.title('Histogram of Admission Chance')
plt.xlabel('Admission Chance')
plt.ylabel('Frequency of Chance')
plt.show()

# %%
# Line Plot for Research Output and The Chance of Admission

plt.figure(figsize=(12,8))
plt.plot(range(len(df[df['Research']==1])), df[df['Research']==1]['Chance of Admit '], color='orange')
plt.plot(range(len(df[df['Research']==0])), df[df['Research']==0]['Chance of Admit '], color='olive')
plt.show()

# %%
# Scatter Plot of University Rating and The Chance of Admission

df.boxplot(column='Chance of Admit ',by='University Rating',grid=False,figsize=(12,8))
plt.title('The Chance of Admission for University Ratings')
plt.xlabel('University Rating')
plt.ylabel('Chance of Admission')
plt.show()

# %% [markdown]
# # Data Preprocessing Steps :

# %%
# Extracting x and y from the dataset

x = df.iloc[:,0:-1].values
y = df.iloc[:,-1].values

# %%
print(x)
# Out:
# [[337.   118.     4.   ...   4.5    9.65   1.  ]
#  [324.   107.     4.   ...   4.5    8.87   1.  ]
#  [316.   104.     3.   ...   3.5    8.     1.  ]
#  ...
#  [330.   120.     5.   ...   5.     9.56   1.  ]
#  [312.   103.     4.   ...   5.     8.43   0.  ]
#  [327.   113.     4.   ...   4.5    9.04   0.  ]]

# %%
print(y)
# Out:
# [0.92 0.76 0.72 0.8  0.65 0.9  0.75 0.68 0.5  0.45 0.52 0.84 0.78 0.62
#  0.61 0.54 0.66 0.65 0.63 0.62 0.64 0.7  0.94 0.95 0.97 0.94 0.76 0.44
#  0.46 0.54 0.65 0.74 0.91 0.9  0.94 0.88 0.64 0.58 0.52 0.48 0.46 0.49
#  0.53 0.87 0.91 0.88 0.86 0.89 0.82 0.78 0.76 0.56 0.78 0.72 0.7  0.64
#  0.64 0.46 0.36 0.42 0.48 0.47 0.54 0.56 0.52 0.55 0.61 0.57 0.68 0.78
#  0.94 0.96 0.93 0.84 0.74 0.72 0.74 0.64 0.44 0.46 0.5  0.96 0.92 0.92
#  0.94 0.76 0.72 0.66 0.64 0.74 0.64 0.38 0.34 0.44 0.36 0.42 0.48 0.86
#  0.9  0.79 0.71 0.64 0.62 0.57 0.74 0.69 0.87 0.91 0.93 0.68 0.61 0.69
#  0.62 0.72 0.59 0.66 0.56 0.45 0.47 0.71 0.94 0.94 0.57 0.61 0.57 0.64
#  0.85 0.78 0.84 0.92 0.96 0.77 0.71 0.79 0.89 0.82 0.76 0.71 0.8  0.78
#  0.84 0.9  0.92 0.97 0.8  0.81 0.75 0.83 0.96 0.79 0.93 0.94 0.86 0.79
#  0.8  0.77 0.7  0.65 0.61 0.52 0.57 0.53 0.67 0.68 0.81 0.78 0.65 0.64
#  0.64 0.65 0.68 0.89 0.86 0.89 0.87 0.85 0.9  0.82 0.72 0.73 0.71 0.71
# ...

# %%
import statsmodels.api as sm
mod = sm.OLS(y,x)
res=mod.fit()
print(res.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.991
# Model:                            OLS   Adj. R-squared (uncentered):              0.991
# Method:                 Least Squares   F-statistic:                              8178.
# Date:                Sun, 30 Aug 2020   Prob (F-statistic):                        0.00
# Time:                        03:22:46   Log-Likelihood:                          635.01
# No. Observations:                 500   AIC:                                     -1256.
# Df Residuals:                     493   BIC:                                     -1227.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# Feature scaling the independent variables(x)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
print(x)
# Out:
# [[ 1.81923762  1.77886545  0.77558214 ...  1.09894429  1.77680627
#    0.88640526]
#  [ 0.66714832 -0.03160087  0.77558214 ...  1.09894429  0.48585943
#    0.88640526]
#  [-0.0418297  -0.52536441 -0.09979274 ...  0.01730621 -0.95404281
#    0.88640526]
#  ...
#  [ 1.19888185  2.10804114  1.65095702 ...  1.63976333  1.62785086
#    0.88640526]
#  [-0.39631872 -0.68995225  0.77558214 ...  1.63976333 -0.24236699
#   -1.12815215]
#  [ 0.93301508  0.95592621  0.77558214 ...  1.09894429  0.76721964
#   -1.12815215]]

# %%
# Splitting x and y into training and test set

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=123)

# %%
print(x_train)
# Out:
# [[-1.01667449 -0.8545401  -0.97516761 ... -1.06433187 -1.54986443
#   -1.12815215]
#  [ 2.08510438  0.95592621  0.77558214 ...  1.63976333  1.92576167
#    0.88640526]
#  [-0.39631872 -1.51289149 -1.85054249 ... -0.52351283 -0.65613201
#    0.88640526]
#  ...
#  [-0.21907421 -0.03160087 -0.97516761 ...  0.55812525 -0.5071766
#   -1.12815215]
#  [ 0.66714832  0.46216267  0.77558214 ...  0.55812525  0.94927624
#    0.88640526]
#  [ 1.19888185  1.12051406  0.77558214 ... -0.52351283  0.98237744
#    0.88640526]]

# %%
#here features means x and labels means y

print('Training Features Shape:', x_train.shape)
print('Training Labels Shape:', y_train.shape)
print('Testing Features Shape:', x_test.shape)
print('Testing Labels Shape:', y_test.shape)
# Out:
# Training Features Shape: (375, 7)
# Training Labels Shape: (375,)
# Testing Features Shape: (125, 7)
# Testing Labels Shape: (125,)

# %% [markdown]
# # Creating and Training the Random Forest Model

# %% [markdown]
# ### while creating the random forest model we need to give the value in the n_estimators argument stating how many times we are applying the decision time algorithm .we can give a value from 10-100. After this we need to give the value for random_state argument.

# %%
# Creating a Random Forest Regression model and fitting it to the training data

from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=100,random_state=42)
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predicting the output

y_pred = rfr.predict(x_test)
print(y_pred)
# Out:
# [0.7931 0.9305 0.5406 0.6353 0.8244 0.6885 0.8961 0.7565 0.6328 0.906
#  0.9179 0.7509 0.9569 0.5549 0.6583 0.8071 0.4589 0.742  0.955  0.6578
#  0.5603 0.7407 0.8603 0.6895 0.8275 0.6384 0.6057 0.6638 0.949  0.8889
#  0.5033 0.7122 0.6676 0.6189 0.4576 0.8651 0.8256 0.7594 0.9396 0.648
#  0.6834 0.7242 0.6352 0.9256 0.7816 0.7187 0.6792 0.6951 0.9618 0.8743
#  0.79   0.5568 0.5664 0.7269 0.5595 0.5615 0.698  0.5265 0.5769 0.7274
#  0.8785 0.9026 0.7365 0.547  0.6559 0.917  0.9143 0.8401 0.8217 0.922
#  0.6197 0.7515 0.6884 0.8337 0.5761 0.9272 0.6579 0.5525 0.5765 0.6842
#  0.746  0.5264 0.9054 0.7747 0.7823 0.7479 0.7471 0.589  0.6919 0.6906
#  0.922  0.8985 0.6538 0.8657 0.6766 0.6777 0.6637 0.6615 0.7629 0.6309
#  0.7202 0.7795 0.7177 0.5425 0.6301 0.7151 0.7544 0.4997 0.7197 0.6957
#  0.8983 0.9015 0.5605 0.6708 0.9412 0.774  0.9609 0.6905 0.6754 0.9209
#  0.8303 0.6972 0.6141 0.9415 0.6914]

# %%
# Calculate the absolute errors
errors = abs(y_pred - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors),7))
# Out:
# Mean Absolute Error: 0.0419208

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
r2 = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
print('r2_score = ',r2)
print('mean absolute error = ',mae)
print('mean squared error = ',mse)
print('root mean squared error = ',rmse)
# Out:
# r2_score =  0.800043594916445
# mean absolute error =  0.04192079999999998
# mean squared error =  0.003917033999999997
# root mean squared error =  0.06258621253918467

# %%
# In order to quantify the usefulness of all the variables in the entire random forest,
# we can look at the relative importances of the variables.
# the importances represent how much including a particular variable improves the prediction
# Get numerical feature importances

importances = list(rfr.feature_importances_)

# List of tuples with variable and importance
x_list = list(df.columns)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(x_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: CGPA                 Importance: 0.79
# Variable: GRE Score            Importance: 0.1
# Variable: TOEFL Score          Importance: 0.04
# Variable: SOP                  Importance: 0.03
# Variable: LOR                  Importance: 0.02
# Variable: University Rating    Importance: 0.01
# Variable: Research             Importance: 0.01

# %%
feature_importance = pd.DataFrame(sorted(zip(rfr.feature_importances_, df.columns)), columns=['Value','Feature'])
plt.figure(figsize=(10, 6)) 
sns.barplot(x="Value", y="Feature", data=feature_importance.sort_values(by="Value", ascending=False))
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Feature'>

# %%
# Isolating GRE Score data

GRE = pd.DataFrame(df['GRE Score'])
GRE.describe()
# Out:
#         GRE Score
# count  500.000000
# mean   316.472000
# std     11.295148
# min    290.000000
# 25%    308.000000
# 50%    317.000000
# 75%    325.000000
# max    340.000000

# %%
# barplot for GRE Scores

plt.figure(figsize=(10,5))
sns.barplot(x=df['GRE Score'].value_counts().index,y=df['GRE Score'].value_counts().values)
plt.xticks(rotation=90)
plt.title('GRE Score')
plt.show()

# %%
# Probability Distribution for GRE 

sns.distplot(GRE).set_title('Probability Distribution for GRE Test Scores', size='20')
plt.show()

# %%
# Isolating CGPA data

CGPA = pd.DataFrame(df['CGPA'])
CGPA.describe()
# Out:
#              CGPA
# count  500.000000
# mean     8.576440
# std      0.604813
# min      6.800000
# 25%      8.127500
# 50%      8.560000
# 75%      9.040000
# max      9.920000

# %%
# barplot for CGPA

plt.figure(figsize=(10,5))
sns.barplot(x=df['CGPA'].value_counts().index,y=df['CGPA'].value_counts().values)
plt.xticks(rotation=90)
plt.title('CGPA')
plt.show()

# %%
# Probability Distribution for CGPA 

sns.distplot(CGPA).set_title('Probability Distribution Plot for CGPA', size='20')
plt.show()

# %%
# Isolating TOEFL Score data

TOEFL = pd.DataFrame(df['TOEFL Score'])
TOEFL.describe()
# Out:
#        TOEFL Score
# count   500.000000
# mean    107.192000
# std       6.081868
# min      92.000000
# 25%     103.000000
# 50%     107.000000
# 75%     112.000000
# max     120.000000

# %%
#Research group 1, ChanceOfAdmit value of all TOEFLScore data by grouping the number of data is performed.

plt.figure(figsize=(10,5)) 
research_predict=df[df['Research']==1.0].groupby('Chance of Admit ')['TOEFL Score'].count()
sns.barplot(x=research_predict.index,y=research_predict.values)
plt.ylabel('Frequency')
plt.title('TOEFL Score vs Chance of Admit')
plt.xlabel('TOEFL Score')
plt.xticks(rotation=90)
plt.show()

# %%
# Probability distribution for TOEFL Scores

sns.distplot(x[:,1]).set_title('Probability Distribution for TOEFL Scores', size='20')
plt.show()

# %%
# Barplot for Research

fig, ax = plt.subplots(figsize=(8,6))
sns.countplot(df['Research'])
plt.title('Research Experience')
plt.ylabel('Number of Applicants')
ax.set_xticklabels(['No Research Experience', 'Has Research Experience'])
# Out:
# [Text(0, 0, 'No Research Experience'), Text(1, 0, 'Has Research Experience')]

# %%
df.describe().plot(kind = "area",fontsize=27, figsize = (20,8), table = True,colormap="rainbow")
plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics of Admissions")
plt.show()
# Out:
# c:\users\91988\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_matplotlib\core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
# Probability Distribution for Chance of Admit

df['Chance of Admit ']
sns.distplot(df['Chance of Admit ']).set_title('Probability Distribution of Chance of Admit', size='20')
plt.show()

# %%
# joint distribution using kernel density estimation
# between CGPA and Chance of Admit

g = sns.jointplot(x[:,5], y, kind="kde", height=7, space=0)
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.title('CGPA vs Chance of Admit')
plt.show()

# %%
# plotting a graph between gre score and cgpa using seaborn library

fig = sns.regplot(x=x[:,0], y=x[:,5], data=df)
plt.title("GRE Score vs CGPA")
plt.show()

# %%
# Define x axis
x_axis = x_test[:,5]

# Build scatterplot
plt.scatter(x_axis, y_test, c = 'b', alpha = 0.5, marker = '.', label = 'Real')
plt.scatter(x_axis, y_pred, c = 'r', alpha = 0.5, marker = '.', label = 'Predicted')
plt.plot(x_test[:,5], y_pred ,c='red')
plt.title('CGPA vs Chance of Admit')
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.grid(color = '#D3D3D3', linestyle = 'solid')
plt.legend(loc = 'lower right')
plt.show()

# %%
# actual vs predicted graph
# CGPA vs Chance of Admit

true_data = pd.DataFrame(data = {'predictions': y_pred, 'actual': y_test})
true_data['CGPA'] = x_test[:, 5]

# Plot all the data as lines
plt.plot(true_data['predictions'], true_data['actual'], 'b-', label  = 'Chance of Admit', alpha = 1.0)
plt.plot(true_data['predictions'], true_data['CGPA'], 'y-', label  = 'CGPA', alpha = 1.0)

# Formatting plot
plt.legend()
plt.xticks(rotation = '60')

# Lables and title
plt.xlabel('CGPA')
plt.ylabel('Chance of Admit')
plt.title('Scores vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'Scores vs Chance of Admit')

# %%
# actual vs predicted graph
# GRE Score vs Chance of Admit

true_data = pd.DataFrame(data = {'predictions': y_pred, 'actual': y_test})
true_data['GRE Score'] = x_test[:, 0]

# Plot all the data as lines
plt.plot(true_data['predictions'], true_data['actual'], 'b-', label  = 'Chance of Admit', alpha = 1.0)
plt.plot(true_data['predictions'], true_data['GRE Score'], 'k-', label = 'GRE Score', alpha = 0.8)

# Formatting plot
plt.legend()
plt.xticks(rotation = '60')

# Lables and title
plt.xlabel('GRE Score')
plt.ylabel('Chance of Admit')
plt.title('Scores vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'Scores vs Chance of Admit')

# %%
# actual vs predicted graph
# TOEFL Score vs Chance of Admit

true_data = pd.DataFrame(data = {'predictions': y_pred, 'actual': y_test})
true_data['TOEFL Score'] = x_test[:, 1]

# Plot all the data as lines
plt.plot(true_data['predictions'], true_data['actual'], 'b-', label  = 'Chance of Admit', alpha = 1.0)
plt.plot(true_data['predictions'], true_data['TOEFL Score'], 'r-', label = 'TOEFL Score', alpha = 0.3)

# Formatting plot
plt.legend()
plt.xticks(rotation = '60')

# Lables and title
plt.xlabel('TOEFL Scores')
plt.ylabel('Chance of Admit')
plt.title('Scores vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'Scores vs Chance of Admit')

# %%
# actual vs predicted graph
true_data = pd.DataFrame(data = {'predictions': y_pred, 'actual': y_test})
true_data['CGPA'] = x_test[:, 5]
true_data['GRE Score'] = x_test[:, 0]
true_data['TOEFL Score'] = x_test[:, 1]

# Plot all the data as lines
plt.plot(true_data['predictions'], true_data['actual'], 'b-', label  = 'Chance of Admit', alpha = 1.0)
plt.plot(true_data['predictions'], true_data['CGPA'], 'y-', label  = 'CGPA', alpha = 1.0)
plt.plot(true_data['predictions'], true_data['GRE Score'], 'k-', label = 'GRE Score', alpha = 0.8)
plt.plot(true_data['predictions'], true_data['TOEFL Score'], 'r-', label = 'TOEFL Score', alpha = 0.3)

# Formatting plot
plt.legend()
plt.xticks(rotation = '60')

# Lables and title
plt.xlabel('Scores')
plt.ylabel('Chance of Admit')
plt.title('Scores vs Chance of Admit')
# Out:
# Text(0.5, 1.0, 'Scores vs Chance of Admit')

# %%
# 3d plot of actual vs predicted graph

from mpl_toolkits import mplot3d
fig=plt.figure(figsize=(8,8))
ax=plt.axes(projection="3d")
ax.scatter3D(x_test[:,0],x_test[:,1],y_test,c='red')
ax.scatter3D(x_test[:,0],x_test[:,1],y_pred,c='blue')
ax.set_xlabel('GRE Score')
ax.set_ylabel('TOEFEL Score')
ax.set_zlabel('Chance of Admit')
plt.show()

# %%
# actual vs predicted graph

plt.scatter(y_test,y_pred,c='blue')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.title("Actual vs Predicted Values")
plt.show()
